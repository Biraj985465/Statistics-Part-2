# %% [markdown]
# # Assignment Questions (Statistics Part 2)

# %% [markdown]
# 1. What is hypothesis testing in statistics ?

# %% [markdown]
#   - Hypothesis testing helps determine if the evidence from the sample is strong enough to infer that a certain condition holds for the entire population, or if any observed effect is likely due to random chance.

# %% [markdown]
# 2. What is the null hypothesis, and how does it differ from the alternative hypothesis ?

# %% [markdown]
#   - The null hypothesis is the default assumption that there is no effect, no difference, or no relationship in the population. The alternative hypothesis is what you are trying to find evidence for. It suggests that there is an effect, difference, or relationship.

# %% [markdown]
# 3. What is the significance level in hypothesis testing, and why is it important ?

# %% [markdown]
#   -
# *   The significance level α defines the cutoff for rejecting the null hypothesis.
# *   It helps guard against making a false discovery.
# *   Picking the right α depends on how serious the consequences of a Type I error are in your context.

# %% [markdown]
# 4.  What does a P-value represent in hypothesis testing ?

# %% [markdown]
#   -
# *   A p-value tells you how likely your results are if the null hypothesis is true.
# *   It’s compared to a significance level (α) to decide whether to reject H₀.
# *   Smaller p-values mean stronger evidence against the null hypothesis.

# %% [markdown]
# 5. How do you interpret the P-value in hypothesis testing ?

# %% [markdown]
#   - Type I Error (False Positive)
#   . Definition: Rejecting the null hypothesis when it is actually true.
#   . You think there is an effect, but there really isn't.
#   . Probability of making a Type I error is α (the significance level, usually 0.05).
#
#   - Type II Error (False Negative)
#   . Definition: Failing to reject the null hypothesis when the alternative hypothesis is true.
#   . You think there is no effect, but there is one.
#   . Probability of making a Type II error is β.
#   . Power of the test = 1 − β → This is the probability of correctly rejecting a false null hypothesis.

# %% [markdown]
#   - Interpreting the p-value correctly is key to making sound conclusions in hypothesis testing.

# %% [markdown]
# 6. What are Type 1 and Type 2 errors in hypothesis testing ?

# %% [markdown]
#   - Type I Error (False Positive):Rejecting the null hypothesis (H₀) when it is actually true. it means: You conclude there is an effect or difference when there really isn’t.
#   - Type II Error (False Negative): Failing to reject the null hypothesis (H₀) when the alternative hypothesis (H₁) is actually true. it means: You conclude there is no effect or difference when there actually is one.

# %% [markdown]
# 7. What is the difference between a one-tailed and a two-tailed test in hypothesis testing ?

# %% [markdown]
#   - One-tailed test checks if the parameter is greater than or less than a value.
#   - Two-tailed test checks if the parameter is different (either greater or less).

# %% [markdown]
# 8.  What is the Z-test, and when is it used in hypothesis testing ?

# %% [markdown]
#   - The Z-test is a statistical test used to determine whether there is a significant difference between a sample statistic (usually the sample mean) and a known population parameter (usually the population mean), assuming the population standard deviation is known.
#   - Known population standard deviation: The Z-test requires that the population standard deviation is known, which is often unrealistic but applicable in some cases.
#   - Typically used when the sample size is large leveraging the Central Limit Theorem which states the sampling distribution of the mean is approximately normal.
#   - Testing hypotheses about means: Commonly used for testing the difference between a sample mean and a population mean, or comparing two sample means if population variances are known.

# %% [markdown]
# 9.  How do you calculate the Z-score, and what does it represent in hypothesis testing ?

# %% [markdown]
#   - A Z-score (also called a standard score) measures how many standard deviations a data point (or sample mean) is from the mean of a distribution.
#
#   -  For an individual data point x:- z = X- 𝜇/σ

# %% [markdown]
# 10. What is the T-distribution, and when should it be used instead of the normal distribution ?

# %% [markdown]
#   - The T-distribution (also called Student’s t-distribution) is a probability distribution that looks similar to the normal distribution (bell-shaped and symmetric) but has heavier tails.
#   - These heavier tails mean there is more probability in the extremes, which accounts for extra uncertainty when estimating the population standard deviation from a small sample.
#     - the T-distribution used When the population standard deviation is unknown and you estimate it using the sample standard deviation When the sample size is small, typically n < 30 so the Central Limit Theorem cannot guarantee that the sampling distribution of the mean is normal.
#   - For inference about the population mean based on small samples or unknown variance.

# %% [markdown]
# 11. What is the difference between a Z-test and a T-test ?

# %% [markdown]
#   - Z-test assumes known population variance and relies on the normal distribution.
#   - T-test estimates population variance from the sample and accounts for extra uncertainty with the t-distribution, especially important for small samples.

# %% [markdown]
# 12.  What is the T-test, and how is it used in hypothesis testing ?

# %% [markdown]
#   - A T-test is a statistical test used to compare means and determine if there is a significant difference between:
#
# *   A sample mean and a known or hypothesized population mean (one-sample T-test),
# *   The means of two independent groups (independent two-sample T-test),
# *   Or the means of two related groups, like before-and-after measurements (paired T-test).
#   - the T-test used in hypothesis testing
# *   Formulate hypotheses
# *   Calculate the t-statistic
# *   Determine degrees of freedom (df)
# *   Find the p-value
# *   Make a decision

# %% [markdown]
# 13. What is the relationship between Z-test and T-test in hypothesis testing ?

# %% [markdown]
#   - Both test the mean
#   - Underlying distribution differences
#   - Sample size effect
#   - Formula similarity

# %% [markdown]
# 14. What is a confidence interval, and how is it used to interpret statistical results ?

# %% [markdown]
#   - A confidence interval is a range of values, derived from sample data, that is likely to contain the true population parameter (such as the mean) with a specified level of confidence.
#   - is it used to interpret results
#   1.   Range of plausible values: The CI provides a range of plausible values for the population parameter.
#   2.   Assess significance: If a hypothesized value (e.g., null hypothesis mean) lies outside the confidence interval, it suggests that the value is unlikely given the data.
#   3.   Precision indicator: Narrow intervals mean more precise estimates; wide intervals indicate more uncertainty.
#   4.   Communicates uncertainty: More informative than just a point estimate because it quantifies uncertainty.

# %% [markdown]
# 15. What is the margin of error, and how does it affect the confidence interval ?

# %% [markdown]
#   - The margin of error is the amount added to and subtracted from a sample estimate (like the sample mean) to create a confidence interval. It represents the maximum expected difference between the true population parameter and the sample estimate due to sampling variability.
#
#     - The width of the confidence interval is directly proportional to the margin of error:
# *   Confidence Interval = Estimate ± Margin of Error
# *   Larger margin of error → wider confidence interval → more uncertainty in the estimate.
# *   Smaller margin of error → narrower confidence interval → more precise estimate.

# %% [markdown]
# 16. How is Bayes' Theorem used in statistics, and what is its significance ?

# %% [markdown]
#   - Bayes’ Theorem used in statistics-
#
# *   Updating beliefs
# *   Incorporating prior knowledge
# *   Model parameter estimation
# *   Decision making under uncertainty
#
#   - significant
# *   Flexibility
# *   Interpretability
# *   Applications
# *   Foundation of Bayesian statistics

# %% [markdown]
# 17. What is the Chi-square distribution, and when is it used ?

# %% [markdown]
#   - The Chi-square distribution is central in hypothesis testing involving categorical data and variance estimation.
#   - Its value comes from summing squared standard normal variables, connecting it to variance and categorical frequencies.

# %% [markdown]
# 18.  What is the Chi-square goodness of fit test, and how is it applied ?

# %% [markdown]
#   - The Chi-square goodness-of-fit test is a statistical test used to determine whether an observed frequency distribution of a categorical variable matches an expected distribution.
#   --- it used
#
# *   To check if a sample fits a particular probability distribution (e.g., uniform, binomial, Poisson).
# *   To test whether observed data matches expected proportions or probabilities.

# %% [markdown]
# 19. What is the F-distribution, and when is it used in hypothesis testing ?

# %% [markdown]
#   - The F-distribution is a continuous probability distribution that arises as the ratio of two independent Chi-square distributed variables, each divided by their respective degrees of freedom.
#   -  F-distribution used in hypothesis testing
# *   Testing equality of variances:The F-test can compare variances of two normally distributed populations.
# *   ANOVA (Analysis of Variance):The F-distribution is fundamental in ANOVA tests, which compare means across three or more groups by analyzing variance between groups relative to variance within groups.
# *   Regression analysis:It is used to test the overall significance of a regression model by comparing explained variance to unexplained variance.

# %% [markdown]
# 20. What is an ANOVA test, and what are its assumptions ?

# %% [markdown]
#   - ANOVA stands for Analysis of Variance. It’s a statistical method used to:
#
# 1.   Compare the means of three or more groups to see if at least one group mean is significantly different from the others.
# 2.   Instead of doing multiple t-tests (which increases error), ANOVA tests all groups simultaneously.
#
#   - Key Assumptions of ANOVA
#
# 1.   Independence: Observations are independent both within and across groups.
# 2.   Normality: The data in each group are approximately normally distributed.
# 3.   Homogeneity of variances (Homoscedasticity): The variances across groups are roughly equal.

# %% [markdown]
# 21. What are the different types of ANOVA tests ?

# %% [markdown]
#   - different types of ANOVA tests--
# 1.   One-Way ANOVA
# 2.   Two-Way ANOVA (Factorial ANOVA)
# 3.   Repeated Measures ANOVA
# 4.   Mixed-Design ANOVA (Split-Plot ANOVA)
# 5.   MANOVA (Multivariate ANOVA)

# %% [markdown]
# 22. What is the F-test, and how does it relate to hypothesis testing ?

# %% [markdown]
#   - The F-test is a statistical test that uses the F-distribution to compare two variances or to test the overall significance in models involving multiple groups or variables.
#
#    - he F-test relate to hypothesis testing:
# 1.   The F-test is used to decide between the null and alternative hypotheses by comparing variances or group means.
# 2.   Null Hypothesis: Assumes that the variances or group means are equal (no effect or no difference).
# 3.   Alternative Hypothesis: Assumes that there is a difference in variances or at least one group mean is different.

# %% [markdown]
# # Practical Part - 1

# %% [markdown]
# 1. Write a Python program to generate a random variable and display its value.

# %%
# Generate a random integer between 1 and 100
import random

random_value = random.randint(1, 100)
print(f"Random integer value: {random_value}")
# Out:
# Random integer value: 89

# %%
# Generate a random float between 0 and 1
import random

random_value = random.random()
print(f"Random float value: {random_value}")
# Out:
# Random float value: 0.79686358886549

# %% [markdown]
# 2. Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

low = 1
high = 7

dist = randint(low, high)

x = np.arange(low, high)

pmf = dist.pmf(x)

plt.stem(x, pmf, basefmt=" ", use_line_collection=True)
plt.xlabel('Value')
plt.ylabel('Probability')
plt.title('Discrete Uniform Distribution PMF')
plt.xticks(x)
plt.ylim(0, max(pmf) + 0.05)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# 3. Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.

# %%
def bernoulli_pmf(x, p):
    """
    Calculate the PMF of a Bernoulli distribution.

    Parameters:
        x (int): 0 or 1 (outcome)
        p (float): probability of success (0 <= p <= 1)

    Returns:
        float: probability of outcome x
    """
    if x not in (0, 1):
        raise ValueError("x must be 0 or 1 for Bernoulli distribution")
    if not (0 <= p <= 1):
        raise ValueError("p must be between 0 and 1")

    return p**x * (1 - p)**(1 - x)

p_success = 0.7
print(f"P(X=1) = {bernoulli_pmf(1, p_success):.3f}")
print(f"P(X=0) = {bernoulli_pmf(0, p_success):.3f}")
# Out:
# P(X=1) = 0.700
# P(X=0) = 0.300

# %% [markdown]
# 4. Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt

n = 10
p = 0.5
size = 1000

data = np.random.binomial(n, p, size)

plt.hist(data, bins=np.arange(n+2)-0.5, edgecolor='black', alpha=0.7)
plt.xlabel('Number of Successes')
plt.ylabel('Frequency')
plt.title(f'Histogram of Binomial Distribution (n={n}, p={p})')
plt.xticks(range(n+1))
plt.grid(axis='y')
plt.show()

# %% [markdown]
# 5. Create a Poisson distribution and visualize it using Python.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

lambda_ = 4

x = np.arange(0, 15)

pmf = poisson.pmf(x, mu=lambda_)

plt.stem(x, pmf, basefmt=" ")
plt.xlabel('Number of Events')
plt.ylabel('Probability')
plt.title(f'Poisson Distribution PMF (λ = {lambda_})')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# 6. Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

a, b = 1, 6

dist = randint(a, b+1)

x = np.arange(a, b+1)

cdf = dist.cdf(x)

plt.step(x, cdf, where='post')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.title('CDF of Discrete Uniform Distribution')
plt.xticks(x)
plt.ylim(0, 1.05)
plt.grid(True)
plt.show()

# %% [markdown]
# 7. Generate a continuous uniform distribution using NumPy and visualize it.

# %%
import numpy as np
import matplotlib.pyplot as plt

a = 0
b = 1

x = np.linspace(a - 0.1, b + 0.1, 1000)

pdf = np.where((x >= a) & (x <= b), 1/(b - a), 0)

plt.plot(x, pdf, label='Uniform PDF')
plt.fill_between(x, pdf, alpha=0.3)
plt.title('Continuous Uniform Distribution PDF')
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.ylim(0, 1.2 / (b - a))
plt.grid(True)
plt.show()

# %% [markdown]
# 8. Simulate data from a normal distribution and plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt

mu = 0
sigma = 1
size = 1000

data = np.random.normal(mu, sigma, size)

plt.hist(data, bins=30, edgecolor='black', alpha=0.7, density=True)
plt.title('Histogram of Simulated Normal Distribution')
plt.xlabel('Value')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %% [markdown]
# 9. Write a Python function to calculate Z-scores from a dataset and plot them.

# %%
import numpy as np
import matplotlib.pyplot as plt

def calculate_and_plot_z_scores(data):
    """
    Calculate Z-scores of the input data and plot them.

    Parameters:
        data (list or np.array): Numeric dataset

    Returns:
        z_scores (np.array): Array of Z-scores
    """
    data = np.array(data)
    mean = np.mean(data)
    std = np.std(data, ddof=1)
    z_scores = (data - mean) / std

    plt.scatter(range(len(data)), z_scores, color='blue')
    plt.axhline(0, color='red', linestyle='--', label='Mean (Z=0)')
    plt.axhline(1, color='green', linestyle='--', label='Z=1')
    plt.axhline(-1, color='green', linestyle='--', label='Z=-1')
    plt.axhline(2, color='orange', linestyle='--', label='Z=2')
    plt.axhline(-2, color='orange', linestyle='--', label='Z=-2')
    plt.xlabel('Index')
    plt.ylabel('Z-score')
    plt.title('Z-scores of the Dataset')
    plt.legend()
    plt.grid(True)
    plt.show()

    return z_scores

sample_data = [10, 12, 15, 14, 13, 9, 11, 16, 18, 14]
z_scores = calculate_and_plot_z_scores(sample_data)
print("Z-scores:", z_scores)
# Out:
# Z-scores: [-1.15071192 -0.43151697  0.64727546  0.28767798 -0.0719195  -1.5103094
#  -0.79111445  1.00687293  1.72606789  0.28767798]

# %% [markdown]
# 10.  Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

lam = 1.0

sample_size = 30

num_experiments = 1000

sample_means = []
for _ in range(num_experiments):
    sample = np.random.exponential(scale=1/lam, size=sample_size)
    sample_means.append(np.mean(sample))

sample_means = np.array(sample_means)

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
data = np.random.exponential(scale=1/lam, size=1000)
sns.histplot(data, bins=30, kde=True, color='skyblue')
plt.title('Original Exponential Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
sns.histplot(sample_means, bins=30, kde=True, color='salmon')
plt.title(f'Distribution of Sample Means (n={sample_size})')
plt.xlabel('Sample Mean')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# 11. Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

mu = 50
sigma = 10

sample_size = 30
num_samples = 1000

sample_means = []
for _ in range(num_samples):
    sample = np.random.normal(mu, sigma, sample_size)
    sample_means.append(np.mean(sample))

sample_means = np.array(sample_means)

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
data = np.random.normal(mu, sigma, 1000)
sns.histplot(data, bins=30, kde=True, color='lightblue')
plt.title('Original Normal Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
sns.histplot(sample_means, bins=30, kde=True, color='lightcoral')
plt.title(f'Distribution of Sample Means (n={sample_size})')
plt.xlabel('Sample Mean')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# 12. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1).

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal():

    x = np.linspace(-4, 4, 1000)

    pdf = norm.pdf(x, loc=0, scale=1)

    plt.plot(x, pdf, label='Standard Normal PDF', color='blue')
    plt.fill_between(x, pdf, alpha=0.2, color='blue')

    plt.title('Standard Normal Distribution (mean=0, std=1)')
    plt.xlabel('x')
    plt.ylabel('Probability Density')
    plt.grid(True)
    plt.legend()
    plt.show()

plot_standard_normal()

# %% [markdown]
# 13. Generate random variables and calculate their corresponding probabilities using the binomial distribution.

# %%
import numpy as np
from scipy.stats import binom

n = 10
p = 0.5
size = 15

random_vars = np.random.binomial(n, p, size)

probabilities = binom.pmf(random_vars, n, p)

for val, prob in zip(random_vars, probabilities):
    print(f"Value: {val}, Probability (PMF): {prob:.4f}")
# Out:
# Value: 6, Probability (PMF): 0.2051
# Value: 7, Probability (PMF): 0.1172
# Value: 6, Probability (PMF): 0.2051
# Value: 5, Probability (PMF): 0.2461
# Value: 5, Probability (PMF): 0.2461
# Value: 6, Probability (PMF): 0.2051
# Value: 3, Probability (PMF): 0.1172
# Value: 3, Probability (PMF): 0.1172
# Value: 4, Probability (PMF): 0.2051
# Value: 6, Probability (PMF): 0.2051
# Value: 3, Probability (PMF): 0.1172
# Value: 4, Probability (PMF): 0.2051
# Value: 4, Probability (PMF): 0.2051
# Value: 5, Probability (PMF): 0.2461
# Value: 5, Probability (PMF): 0.2461

# %% [markdown]
# 14. Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def calculate_z_score(data, x):
    """
    Calculate the Z-score of a data point x in the dataset.

    Parameters:
        data (list or np.array): Dataset
        x (float): Data point to calculate Z-score for

    Returns:
        float: Z-score of x
    """
    mean = np.mean(data)
    std = np.std(data, ddof=1)
    z = (x - mean) / std
    return z

def plot_z_on_standard_normal(z):
    """
    Plot the standard normal distribution and mark the Z-score.

    Parameters:
        z (float): Z-score to mark on the plot
    """
    x = np.linspace(-4, 4, 1000)
    y = norm.pdf(x)

    plt.plot(x, y, label='Standard Normal Distribution')
    plt.fill_between(x, y, alpha=0.2)

    plt.axvline(z, color='red', linestyle='--', label=f'Z = {z:.2f}')
    plt.scatter(z, norm.pdf(z), color='red')

    plt.title('Z-score on Standard Normal Distribution')
    plt.xlabel('Z')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.grid(True)
    plt.show()

data = [12, 15, 14, 10, 18, 20, 22, 19, 16, 14]
data_point = 18

z_score = calculate_z_score(data, data_point)
print(f"Data point: {data_point}")
print(f"Z-score: {z_score:.2f}")

plot_z_on_standard_normal(z_score)
# Out:
# Data point: 18
# Z-score: 0.53

# %% [markdown]
# 15.  Implement hypothesis testing using Z-statistics for a sample dataset.

# %%
import numpy as np
from scipy.stats import norm

def z_test(sample, pop_mean, pop_std, alpha=0.05):
    """
    Perform a one-sample Z-test.

    Parameters:
        sample (list or np.array): sample data
        pop_mean (float): population mean under the null hypothesis
        pop_std (float): known population standard deviation
        alpha (float): significance level (default 0.05)

    Returns:
        z_stat (float): calculated Z statistic
        p_value (float): two-tailed p-value
        reject_null (bool): whether to reject the null hypothesis
    """
    sample = np.array(sample)
    n = len(sample)
    sample_mean = np.mean(sample)

    z_stat = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))

    p_value = 2 * (1 - norm.cdf(abs(z_stat)))

    reject_null = p_value < alpha

    return z_stat, p_value, reject_null

sample_data = [102, 100, 98, 97, 105, 101, 99, 103, 104, 96]
population_mean = 100
population_std = 5
alpha = 0.05

z_stat, p_value, reject = z_test(sample_data, population_mean, population_std, alpha)

print(f"Z statistic: {z_stat:.3f}")
print(f"P-value: {p_value:.4f}")
print(f"Reject null hypothesis? {'Yes' if reject else 'No'}")
# Out:
# Z statistic: 0.316
# P-value: 0.7518
# Reject null hypothesis? No

# %% [markdown]
# 16. Create a confidence interval for a dataset using Python and interpret the result.

# %%
import numpy as np
from scipy import stats

def confidence_interval(data, confidence=0.95):
    """
    Calculate the confidence interval for the mean of the data.

    Parameters:
        data (list or np.array): Sample data
        confidence (float): Confidence level (default 0.95)

    Returns:
        (float, float): Lower and upper bounds of the confidence interval
    """
    data = np.array(data)
    n = len(data)
    mean = np.mean(data)
    std_err = stats.sem(data)

    t_crit = stats.t.ppf((1 + confidence) / 2, df=n-1)

    margin_error = t_crit * std_err
    lower = mean - margin_error
    upper = mean + margin_error

    return lower, upper

sample_data = [12, 15, 14, 10, 18, 20, 22, 19, 16, 14]

lower_bound, upper_bound = confidence_interval(sample_data, confidence=0.95)
mean_value = np.mean(sample_data)

print(f"Sample Mean: {mean_value:.2f}")
print(f"95% Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")
print(f"Interpretation: We are 95% confident that the true population mean lies within this interval.")
# Out:
# Sample Mean: 16.00
# 95% Confidence Interval: (13.32, 18.68)
# Interpretation: We are 95% confident that the true population mean lies within this interval.

# %% [markdown]
# 17. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.

# %%
import numpy as np
from scipy import stats

np.random.seed(42)
mu = 100
sigma = 15
sample_size = 50

data = np.random.normal(mu, sigma, sample_size)

def confidence_interval(data, confidence=0.95):
    n = len(data)
    mean = np.mean(data)
    std_err = stats.sem(data)
    t_crit = stats.t.ppf((1 + confidence) / 2, df=n-1)
    margin_error = t_crit * std_err
    lower = mean - margin_error
    upper = mean + margin_error
    return mean, lower, upper

mean, lower_bound, upper_bound = confidence_interval(data)

print(f"Sample Mean: {mean:.2f}")
print(f"95% Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")
print(f"Interpretation: We are 95% confident that the true population mean lies between {lower_bound:.2f} and {upper_bound:.2f}.")
# Out:
# Sample Mean: 96.62
# 95% Confidence Interval: (92.64, 100.60)
# Interpretation: We are 95% confident that the true population mean lies between 92.64 and 100.60.

# %% [markdown]
# 18. Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

mu = 0
sigma = 1

x = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)

pdf = norm.pdf(x, loc=mu, scale=sigma)

plt.plot(x, pdf, label=f'Normal PDF\n$\mu={mu}, \sigma={sigma}$', color='blue')
plt.fill_between(x, pdf, alpha=0.2, color='blue')
plt.title('Probability Density Function of Normal Distribution')
plt.xlabel('x')
plt.ylabel('Density')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# 19.  Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.

# %%
import numpy as np
from scipy.stats import poisson
import matplotlib.pyplot as plt

lambda_ = 3

x_values = np.arange(0, 15)

cdf_values = poisson.cdf(x_values, mu=lambda_)

for x, cdf in zip(x_values, cdf_values):
    print(f"P(X ≤ {x}) = {cdf:.4f}")

plt.step(x_values, cdf_values, where='post', label=f'Poisson CDF (λ={lambda_})')
plt.xlabel('k')
plt.ylabel('P(X ≤ k)')
plt.title('Poisson Distribution CDF')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# P(X ≤ 0) = 0.0498
# P(X ≤ 1) = 0.1991
# P(X ≤ 2) = 0.4232
# P(X ≤ 3) = 0.6472
# P(X ≤ 4) = 0.8153
# P(X ≤ 5) = 0.9161
# P(X ≤ 6) = 0.9665
# P(X ≤ 7) = 0.9881
# P(X ≤ 8) = 0.9962
# P(X ≤ 9) = 0.9989
# P(X ≤ 10) = 0.9997
# P(X ≤ 11) = 0.9999
# P(X ≤ 12) = 1.0000
# P(X ≤ 13) = 1.0000
# P(X ≤ 14) = 1.0000

# %% [markdown]
# 20.  Simulate a random variable using a continuous uniform distribution and calculate its expected value.

# %%
import numpy as np

a = 2
b = 10
sample_size = 10000

samples = np.random.uniform(a, b, sample_size)

expected_value_theoretical = (a + b) / 2

expected_value_sample = np.mean(samples)

print(f"Theoretical Expected Value: {expected_value_theoretical:.2f}")
print(f"Sample Mean (Estimated Expected Value): {expected_value_sample:.2f}")
# Out:
# Theoretical Expected Value: 6.00
# Sample Mean (Estimated Expected Value): 5.95

# %% [markdown]
# 21. Write a Python program to compare the standard deviations of two datasets and visualize the difference.

# %%
import numpy as np
import matplotlib.pyplot as plt

data1 = np.random.normal(loc=50, scale=5, size=1000)
data2 = np.random.normal(loc=50, scale=10, size=1000)

std1 = np.std(data1, ddof=1)
std2 = np.std(data2, ddof=1)

print(f"Standard Deviation of Dataset 1: {std1:.2f}")
print(f"Standard Deviation of Dataset 2: {std2:.2f}")

plt.figure(figsize=(12,6))
plt.hist(data1, bins=30, alpha=0.6, label=f'Dataset 1 (std={std1:.2f})')
plt.hist(data2, bins=30, alpha=0.6, label=f'Dataset 2 (std={std2:.2f})')
plt.title('Comparison of Standard Deviations')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Standard Deviation of Dataset 1: 5.10
# Standard Deviation of Dataset 2: 9.59

# %% [markdown]
# 22. Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.

# %%
import numpy as np
from scipy.stats import iqr

np.random.seed(0)
data = np.random.normal(loc=50, scale=10, size=1000)

data_range = np.max(data) - np.min(data)

data_iqr = iqr(data)

print(f"Range of data: {data_range:.2f}")
print(f"Interquartile Range (IQR): {data_iqr:.2f}")
# Out:
# Range of data: 58.05
# Interquartile Range (IQR): 13.05

# %% [markdown]
# 23. Implement Z-score normalization on a dataset and visualize its transformation.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore

np.random.seed(42)
data = np.random.normal(loc=50, scale=10, size=1000)

data_normalized = zscore(data)

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.hist(data, bins=30, color='skyblue', edgecolor='black')
plt.title('Original Data Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
plt.hist(data_normalized, bins=30, color='salmon', edgecolor='black')
plt.title('Z-score Normalized Data Distribution')
plt.xlabel('Z-score')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# 24. Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.

# %%
import numpy as np
from scipy.stats import skew, kurtosis

def calculate_skewness_kurtosis(mu=0, sigma=1, size=1000):
    """
    Generate a normal distribution dataset and calculate skewness and kurtosis.

    Parameters:
        mu (float): Mean of the normal distribution.
        sigma (float): Standard deviation of the normal distribution.
        size (int): Number of data points.

    Returns:
        tuple: (skewness, kurtosis)
    """

    data = np.random.normal(loc=mu, scale=sigma, size=size)

    skewness = skew(data)

    kurt = kurtosis(data)

    return skewness, kurt

skewness, kurt = calculate_skewness_kurtosis(mu=0, sigma=1, size=1000)
print(f"Skewness: {skewness:.4f}")
print(f"Kurtosis: {kurt:.4f}  (Note: For normal distribution, kurtosis ~ 0)")
# Out:
# Skewness: -0.0493
# Kurtosis: 0.0521  (Note: For normal distribution, kurtosis ~ 0)

# %% [markdown]
# # Practical Part - 2

# %% [markdown]
# 1. Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results.

# %%
import numpy as np
from scipy.stats import norm

population_mean = 100
population_std = 15

sample = [108, 112, 105, 98, 115, 100, 102, 110, 107, 109]
sample_size = len(sample)
sample_mean = np.mean(sample)

z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

p_value = 2 * (1 - norm.cdf(abs(z_score)))

print("Sample Mean:", sample_mean)
print("Z-score:", z_score)
print("p-value:", p_value)

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: Sample mean is significantly different from population mean.")
else:
    print("Fail to reject the null hypothesis: No significant difference between sample and population mean.")
# Out:
# Sample Mean: 106.6
# Z-score: 1.3914021704740858
# p-value: 0.164103506825787
# Fail to reject the null hypothesis: No significant difference between sample and population mean.

# %% [markdown]
# 2. Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python.

# %%
import numpy as np
from scipy.stats import ttest_1samp

np.random.seed(0)
sample_size = 30
true_mean = 52
simulated_data = np.random.normal(loc=true_mean, scale=5, size=sample_size)

hypothesized_mean = 50

t_stat, p_value = ttest_1samp(simulated_data, hypothesized_mean)

print("Sample Data (first 5):", simulated_data[:5])
print("Sample Mean:", np.mean(simulated_data))
print("T-statistic:", t_stat)
print("P-value:", p_value)

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The sample mean is significantly different from the hypothesized mean.")
else:
    print("Fail to reject the null hypothesis: No significant difference from the hypothesized mean.")
# Out:
# Sample Data (first 5): [60.82026173 54.00078604 56.89368992 63.204466   61.33778995]
# Sample Mean: 54.21428223631587
# T-statistic: 4.195579082381902
# P-value: 0.00023467104623457576
# Reject the null hypothesis: The sample mean is significantly different from the hypothesized mean.

# %% [markdown]
# 3. Implement a one-sample Z-test using Python to compare the sample mean with the population mean.

# %%
import numpy as np
from scipy.stats import norm

sample_data = [102, 98, 101, 104, 100, 99, 103, 97, 100, 105]

population_mean = 100
population_std = 3

sample_mean = np.mean(sample_data)
sample_size = len(sample_data)

z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

p_value = 2 * (1 - norm.cdf(abs(z_score)))

print("Sample Mean:", sample_mean)
print("Z-score:", z_score)
print("P-value:", p_value)

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The sample mean is significantly different from the population mean.")
else:
    print("Fail to reject the null hypothesis: No significant difference from the population mean.")
# Out:
# Sample Mean: 100.9
# Z-score: 0.9486832980505199
# P-value: 0.3427817111479081
# Fail to reject the null hypothesis: No significant difference from the population mean.

# %% [markdown]
# 4. Perform a two-tailed Z-test using Python and visualize the decision region on a plot.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

np.random.seed(42)
sample_size = 50
sample = np.random.normal(loc=103, scale=15, size=sample_size)

population_mean = 100
population_std = 15
alpha = 0.05

sample_mean = np.mean(sample)
z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))
p_value = 2 * (1 - norm.cdf(abs(z_score)))

z_critical = norm.ppf(1 - alpha/2)

print("Sample Mean:", sample_mean)
print("Z-score:", z_score)
print("P-value:", p_value)

if abs(z_score) > z_critical:
    print("Reject null hypothesis: Sample mean is significantly different.")
else:
    print("Fail to reject null hypothesis: No significant difference.")

x = np.linspace(-4, 4, 1000)
y = norm.pdf(x, 0, 1)

plt.figure(figsize=(10, 6))
plt.plot(x, y, label='Standard Normal Distribution')
plt.fill_between(x, y, where=(x < -z_critical) | (x > z_critical), color='red', alpha=0.3, label='Rejection Region (α=0.05)')
plt.axvline(z_score, color='blue', linestyle='--', label=f'Z-score = {z_score:.2f}')
plt.axvline(-z_critical, color='black', linestyle=':', label=f'Z-critical = ±{z_critical:.2f}')
plt.axvline(z_critical, color='black', linestyle=':')

plt.title('Two-Tailed Z-Test: Decision Regions')
plt.xlabel('Z-value')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Sample Mean: 99.61789142115789
# Z-score: -0.18012771149920573
# P-value: 0.8570523077824828
# Fail to reject null hypothesis: No significant difference.

# %% [markdown]
#   5. Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def visualize_type1_type2_errors(mu0, mu1, sigma, n, alpha=0.05, test_type='right'):
    """
    Visualize Type I and Type II errors for a one-tailed hypothesis test.

    Parameters:
        mu0: float - Null hypothesis mean
        mu1: float - Alternative hypothesis mean
        sigma: float - Population standard deviation
        n: int - Sample size
        alpha: float - Significance level (Type I error)
        test_type: str - 'right' or 'left' for one-tailed test
    """
    se = sigma / np.sqrt(n)

    if test_type == 'right':
        z_crit = norm.ppf(1 - alpha)
        crit_val = mu0 + z_crit * se
        beta = norm.cdf((crit_val - mu1) / se)
    else:
        z_crit = norm.ppf(alpha)
        crit_val = mu0 + z_crit * se
        beta = 1 - norm.cdf((crit_val - mu1) / se)

    x = np.linspace(mu0 - 4*se, mu1 + 4*se, 1000)

    y_null = norm.pdf(x, mu0, se)
    y_alt = norm.pdf(x, mu1, se)

    plt.figure(figsize=(10, 6))
    plt.plot(x, y_null, label='Null Hypothesis (H₀)', color='blue')
    plt.plot(x, y_alt, label='Alternative Hypothesis (H₁)', color='green')

    if test_type == 'right':
        plt.fill_between(x, 0, y_null, where=(x > crit_val), color='red', alpha=0.3, label='Type I Error (α)')
        plt.fill_between(x, 0, y_alt, where=(x < crit_val), color='orange', alpha=0.3, label='Type II Error (β)')
    else:
        plt.fill_between(x, 0, y_null, where=(x < crit_val), color='red', alpha=0.3, label='Type I Error (α)')
        plt.fill_between(x, 0, y_alt, where=(x > crit_val), color='orange', alpha=0.3, label='Type II Error (β)')

    plt.axvline(crit_val, color='black', linestyle='--', label=f'Critical Value = {crit_val:.2f}')

    plt.title("Type I and Type II Errors Visualization")
    plt.xlabel("Sample Mean")
    plt.ylabel("Probability Density")
    plt.legend()
    plt.grid(True)
    plt.show()

    print(f"Critical value: {crit_val:.2f}")
    print(f"Type I error (α): {alpha}")
    print(f"Type II error (β): {beta:.3f}")
    print(f"Power of the test (1 - β): {1 - beta:.3f}")

# %% [markdown]
# 6. Write a Python program to perform an independent T-test and interpret the results.

# %%
import numpy as np
from scipy.stats import ttest_ind

group1 = [88, 92, 85, 91, 87, 89, 90, 86, 93, 88]
group2 = [78, 82, 80, 79, 77, 81, 76, 80, 79, 78]

t_stat, p_value = ttest_ind(group1, group2, equal_var=True)

print("Group 1 Mean:", np.mean(group1))
print("Group 2 Mean:", np.mean(group2))
print("T-statistic:", t_stat)
print("P-value:", p_value)

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between the two groups.")
else:
    print("Fail to reject the null hypothesis: No significant difference between the two groups.")
# Out:
# Group 1 Mean: 88.9
# Group 2 Mean: 79.0
# T-statistic: 9.850868183078898
# P-value: 1.1248709732841992e-08
# Reject the null hypothesis: There is a significant difference between the two groups.

# %% [markdown]
# 7.  Perform a paired sample T-test using Python and visualize the comparison results.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_rel

before = np.array([72, 75, 78, 74, 77, 73, 76, 79, 75, 74])
after =  np.array([74, 78, 80, 76, 78, 75, 77, 82, 76, 75])

t_stat, p_value = ttest_rel(before, after)

print("Before Mean:", np.mean(before))
print("After Mean:", np.mean(after))
print("T-statistic:", t_stat)
print("P-value:", p_value)

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: Significant difference between paired samples.")
else:
    print("Fail to reject the null hypothesis: No significant difference between paired samples.")

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
index = np.arange(len(before))
bar_width = 0.35

plt.bar(index, before, bar_width, label='Before', color='skyblue')
plt.bar(index + bar_width, after, bar_width, label='After', color='salmon')
plt.xlabel('Subject')
plt.ylabel('Score')
plt.title('Before vs. After Scores')
plt.legend()

plt.subplot(1, 2, 2)
differences = after - before
plt.axhline(0, color='gray', linestyle='--')
plt.bar(index, differences, color='orange')
plt.xlabel('Subject')
plt.ylabel('Difference (After - Before)')
plt.title('Score Differences per Subject')

plt.tight_layout()
plt.show()
# Out:
# Before Mean: 75.3
# After Mean: 77.1
# T-statistic: -7.216053531635457
# P-value: 4.995767531124341e-05
# Reject the null hypothesis: Significant difference between paired samples.

# %% [markdown]
# 8. Simulate data and perform both Z-test and T-test, then compare the results using Python.

# %%
import numpy as np
from scipy.stats import norm, ttest_1samp
import matplotlib.pyplot as plt

np.random.seed(42)
n = 30
mu_true = 52
pop_mean = 50
pop_std = 5

sample = np.random.normal(loc=mu_true, scale=pop_std, size=n)
sample_mean = np.mean(sample)
sample_std = np.std(sample, ddof=1)

z_score = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))
z_p_value = 2 * (1 - norm.cdf(abs(z_score)))

t_stat, t_p_value = ttest_1samp(sample, pop_mean)

print("=== Sample Statistics ===")
print(f"Sample Mean: {sample_mean:.2f}")
print(f"Sample Std Dev: {sample_std:.2f}")

print("\n=== Z-Test Results ===")
print(f"Z-score: {z_score:.3f}")
print(f"P-value: {z_p_value:.4f}")

print("\n=== T-Test Results ===")
print(f"T-statistic: {t_stat:.3f}")
print(f"P-value: {t_p_value:.4f}")

alpha = 0.05
def decision(p):
    return "Reject H0" if p < alpha else "Fail to reject H0"

print("\n=== Conclusion ===")
print(f"Z-test: {decision(z_p_value)}")
print(f"T-test: {decision(t_p_value)}")

plt.figure(figsize=(8, 4))
plt.hist(sample, bins=10, alpha=0.6, color='skyblue', edgecolor='black')
plt.axvline(pop_mean, color='red', linestyle='--', label='Population Mean (H₀)')
plt.axvline(sample_mean, color='green', linestyle='--', label='Sample Mean')
plt.title("Histogram of Simulated Sample")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# === Sample Statistics ===
# Sample Mean: 51.06
# Sample Std Dev: 4.50
#
# === Z-Test Results ===
# Z-score: 1.160
# P-value: 0.2459
#
# === T-Test Results ===
# T-statistic: 1.289
# P-value: 0.2075
#
# === Conclusion ===
# Z-test: Fail to reject H0
# T-test: Fail to reject H0

# %% [markdown]
# 9. Write a Python function to calculate the confidence interval for a sample mean and explain its significance.

# %%
import numpy as np
from scipy import stats

def confidence_interval(data, confidence=0.95):
    """
    Calculate the confidence interval for the mean of a sample.

    Parameters:
        data (list or array): The sample data
        confidence (float): Confidence level (default is 0.95 for 95%)

    Returns:
        (mean, lower_bound, upper_bound)
    """
    n = len(data)
    mean = np.mean(data)
    sem = stats.sem(data)
    t_crit = stats.t.ppf((1 + confidence) / 2, df=n-1)

    margin_of_error = t_crit * sem
    lower = mean - margin_of_error
    upper = mean + margin_of_error

    return mean, lower, upper

sample_data = [72, 75, 78, 74, 77, 73, 76, 79, 75, 74]
mean, lower, upper = confidence_interval(sample_data, confidence=0.95)

print(f"Sample Mean = {mean:.2f}")
print(f"95% Confidence Interval: ({lower:.2f}, {upper:.2f})")
# Out:
# Sample Mean = 75.30
# 95% Confidence Interval: (73.72, 76.88)

# %% [markdown]
# 10.  Write a Python program to calculate the margin of error for a given confidence level using sample data.

# %%
import numpy as np
from scipy import stats

def margin_of_error(data, confidence=0.95):
    """
    Calculate the margin of error for the sample mean.

    Parameters:
        data (list or array): Sample data
        confidence (float): Confidence level (default 0.95)

    Returns:
        margin_of_error (float)
    """
    n = len(data)
    sem = stats.sem(data)
    t_crit = stats.t.ppf((1 + confidence) / 2, df=n-1)
    moe = t_crit * sem
    return moe

sample_data = [85, 88, 90, 86, 87, 89, 91, 90, 88, 86]
moe = margin_of_error(sample_data, confidence=0.95)

print(f"Margin of Error (95% confidence): {moe:.3f}")
# Out:
# Margin of Error (95% confidence): 1.431

# %% [markdown]
# 11. Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process.

# %%
def bayes_theorem(prior, likelihood, false_positive_rate):
    """
    Compute posterior probability using Bayes' theorem.

    Parameters:
        prior: P(H) - prior probability of hypothesis (disease)
        likelihood: P(E|H) - probability of evidence given hypothesis (true positive rate)
        false_positive_rate: P(E|¬H) - probability of evidence given not hypothesis (false positive rate)

    Returns:
        posterior: P(H|E) - updated probability after observing evidence
    """

    marginal_likelihood = (likelihood * prior) + (false_positive_rate * (1 - prior))

    posterior = (likelihood * prior) / marginal_likelihood
    return posterior

prior_disease = 0.001
true_positive_rate = 0.99
false_positive_rate = 0.05

posterior_prob = bayes_theorem(prior_disease, true_positive_rate, false_positive_rate)

print(f"Posterior probability of having disease given positive test: {posterior_prob:.4f}")
# Out:
# Posterior probability of having disease given positive test: 0.0194

# %% [markdown]
# 12. Perform a Chi-square test for independence between two categorical variables in Python.

# %%
import numpy as np
from scipy.stats import chi2_contingency
data = np.array([[30, 10],
                 [20, 40]])

chi2, p, dof, expected = chi2_contingency(data)

print("Chi-square statistic:", chi2)
print("Degrees of freedom:", dof)
print("P-value:", p)
print("\nExpected frequencies under independence:")
print(expected)

alpha = 0.05
if p < alpha:
    print("\nReject null hypothesis - variables are dependent (associated).")
else:
    print("\nFail to reject null hypothesis - variables are independent.")
# Out:
# Chi-square statistic: 15.041666666666666
# Degrees of freedom: 1
# P-value: 0.00010516355403363098
#
# Expected frequencies under independence:
# [[20. 20.]
#  [30. 30.]]
#
# Reject null hypothesis - variables are dependent (associated).

# %% [markdown]
# 13. Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data.

# %%
import numpy as np

def calculate_expected_frequencies(observed):
    """
    Calculate expected frequencies for a Chi-square test from observed data.

    Parameters:
        observed (2D array): observed frequencies (contingency table)

    Returns:
        expected (2D array): expected frequencies under independence
    """
    observed = np.array(observed)
    row_totals = observed.sum(axis=1).reshape(-1, 1)
    col_totals = observed.sum(axis=0).reshape(1, -1)
    grand_total = observed.sum()

    expected = row_totals @ col_totals / grand_total
    return expected


observed_data = [
    [30, 10],  # Row 1
    [20, 40]   # Row 2
]

expected_freq = calculate_expected_frequencies(observed_data)

print("Observed frequencies:")
print(np.array(observed_data))
print("\nExpected frequencies under independence:")
print(np.round(expected_freq, 2))
# Out:
# Observed frequencies:
# [[30 10]
#  [20 40]]
#
# Expected frequencies under independence:
# [[20. 20.]
#  [30. 30.]]

# %% [markdown]
# 14. Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution.

# %%
from scipy.stats import chisquare

observed = [10, 12, 9, 11, 8, 10]

expected = [10, 10, 10, 10, 10, 10]

chi2_stat, p_value = chisquare(f_obs=observed, f_exp=expected)

print("Chi-square Statistic:", chi2_stat)
print("p-value:", p_value)

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The observed distribution differs from the expected.")
else:
    print("Fail to reject the null hypothesis: No significant difference from expected.")
# Out:
# Chi-square Statistic: 1.0
# p-value: 0.9625657732472964
# Fail to reject the null hypothesis: No significant difference from expected.
